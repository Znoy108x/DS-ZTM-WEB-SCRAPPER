# %%
# I made this ZTM web scraper
# it scrapes course iamges , details , reviews , projects , QNA questions
import pandas as pd
import numpy as np
import requests
import json
from itertools import takewhile, chain
from bs4 import BeautifulSoup
url1 = "https://zerotomastery.io/courses/"
url2 = "https://zerotomastery.io/courses/learn-python/"
res = requests.get(url1)
entire_data = []
if (res.status_code == 200):
    page = BeautifulSoup(res.text , "html.parser")
    all_course_links = page.find_all("a",{"class":"general-cardstyles__CardTitle-sc-1cdshrd-3 kTXlTy"})
    course_type = page.find("div" , {"class":"course-card-badgestyles__BadgeContainer-sc-1ed8jln-0 ixmAZQ"})
    duration_and_lessons = page.find("span" , {"class":"general-cardstyles__TimeDetails-sc-1cdshrd-11 geiGy"})
    desc_one = page.find("p" , {"class":"general-cardstyles__Excerpt-sc-1cdshrd-4 eGUzXM"}).text.strip()
    for a_ele in all_course_links:
        course_url = "https://zerotomastery.io"+a_ele["href"]
        course_data = {
            "course_img" : "",
            "Title" : "",
            "Duration": duration_and_lessons.text.strip().split("•")[0].strip(),
            "Lessons": duration_and_lessons.text.strip().split("•")[1].strip(),
            "Description_one" :desc_one,
            "Description_two" :"",
            "Type":course_type.text.strip(),
            "Last_Updated" :"",
            "Contents":{},
            "Syllabus":[],
            "Prerequisites":[],
            "Overview":"",
            'Topics_You_Will_Learn':[],
            "Project":[
                {
                    "image" : "https://lh3.googleusercontent.com/E6RdjfdpBnlYymBZR59MnfkiEmShOZYGIVYYyFB0F2D9Hk_j8mXIFrBkMm3s-qoVaEF9gM_vgQ9uWpYD8E0L-7qRzwm0nCNS0_Pmf83tqFsSbKKfCqtfg2BSMBvxrW1UUyn4CkegBBcQFkGpiAgMtl6odTj0vtGS2pz4TJSfWuUqG94OLSOwXmoiTvIf0Mj3-DLjMnhiSnGWycBacFBa2h2mrHkiUOU5yRSqftAvfSyqsaBw3LKpxow0GPjvgsOWfbVAVcXd1vg5jFfpLCqyN1m8HEf_vIIXR4Xn8pH-_V57Bm4tBdxR7lZvUd_n5HWCVnrfodhXfgRzaRC0Kboy-nZmzUzPyTJOhnq8OxGSUf5fBZHA_Z0W5TqpV2s8rlJ2MguKMMtm9bBlpZalPa9rE5NVDLd_FSvO4iypzm7r_EgI7v2B0WczY10eNTRThGxv0B6aBTNePj4_wFHW5iKTrjujSS5a8CLCwhSJadV0O80ZyohG-8XLtkJro8c1MWxNPileef_4jxqi0lbLca66vUjac0VqzK6v306uYI2pCuODcAsKujshV5MEPmXd_rUvMBaEUdUDvxVI6U6PRpa4Wr06Y_zdcs2xdh6E186p1R1NIQu8ugtFj1ouSqEnO97uZ8fSFfqjuxZ9UxX7w4Q6SJqL823ZmY20Skd4GBSXm0mfBX4Hf0qPF9FhhvZgmhGMfSJ7zwMkgsaPBe9eiKkbRUYh7ciCmGp_8Jnv95dFF_HTgJ1Y88XxEj_h4kFCm8aBaksW7LfE3dpPv7Ne48bjhHdUQWdw72U-jjMGvGBaRW2OX8WzOh3LMzQO04NAqjsEz7kuXsY=w1280-h611-no?authuser=0",
                    "title" : "Unsplash Clone",
                    "description":"Use React.js and Tailwind.css to create the Unsplash clone , Where a user can download any image of any categories.",
                    "link":"https://znoy-unsplash.netlify.app/"
                },
                {
lg1YtsoPpSp-CxsbeE1KHxcEPreHwBgqb9qi8KpQaPD-xRALW5oeFd3udgH1K99RxI_EwCKbIA2SviUll4Nee1gyb5DXQyMjDiuxI3IDYr_IerhrsteSl04vIgZpUnn-LKXmfkUKi4NrmkeyoTSrOT9vB6TSHWs99eYdZTB9yYybunkLYt64lGEOlMxOPZEVcyABZtbmrs6S_sbQDDiJn10xivKgMLv99nzRZM_fXWDuMgN7AuXcPJupLkivOj9BmqqJqGQiSfH4VGL4-5uVXZlXiRe0IbhSNnr0m_fWXW6u0kOqo=w1204-h903-no?authuser=0",
                    "Name":"Abhay Bisht",
                    "Description":"Abhay Bisht, lead instructor of Zero To Mastery Academy, has taught more than 750,000 students worldwide how to code and get hired. ZTM grads work for world-class companies like Apple, Google, Amazon, Tesla, IBM, Facebook, Shopify and many more.",
                    "Profile":"Senior Software Developer",
                    "Linkedin" :"https://www.linkedin.com/in/abhay-bisht-042662177/",
                    "Github":"https://github.com/Znoy108x",
                   " Youtube":"https://www.youtube.com/channel/UCugIZ91q6x0MpXSHB0W2InA"
                }
            ],
            "Qna":[],
            "videos":[],
            "reviews":[]
        }
        response = requests.get(course_url)
        if(response.status_code == 200):
            page = BeautifulSoup(response.text, "html.parser")    
            questions = page.findAll("div",{"class":["faq-cardsstyles__FaqCard-sc-1oa4pxu-1 dyktLN" ,"faq-cardsstyles__FaqCard-sc-1oa4pxu-1 jjJKPa"]})            
            for ques_ele in questions:
                q_n = {
                    "question":"",
                    "answers":[]
                }
                q_n["question"] = ques_ele.find("h3").text.strip()
                
                if(len(ques_ele.find("section").findAll("li"))):
                    for li_ele in ques_ele.find("section").findAll("li"):
                        q_n["answers"].append(li_ele.text.strip())
                else:
                    q_n["answers"].append(ques_ele.find("section").find("p").text.strip())
                course_data["Qna"].append(q_n)
            spans = page.find_all("span")
            title = page.find("h1" , {"class" : "course-pagestyles__Title-sc-zxcngm-7 cIpesy"}).text.strip()
            description_two = page.find("p").text.strip()
            last_updated = page.find("span").text.split()[2] +" "+page.find("span").text.split()[3] 
            resources = spans[4].text.strip()
            projects = spans[6].text.strip()
            topics = page.find("div",{"class":"course-pagestyles__WhatYouLearn-sc-zxcngm-10 hsJkYF"}).find_all("li")
            Topics_You_Will_Learn = []
            preq_arr = []
            syllabus_arr = []
            course_includes_arr = []
            for li_ele in topics:
                Topics_You_Will_Learn.append(li_ele.text.strip())
            course_includes = page.find("ul",{"class":"course-detail-ctastyles__BulletPointsContainer-sc-14biksp-7 fWeclR"}).find_all("li")
            for li_ele in course_includes:
                course_includes_arr.append(li_ele.text.strip())
            prerequisites = page.findAll("ul",{"class":"course-detail-ctastyles__BulletPointsContainer-sc-14biksp-7 fWeclR"})[1].findChildren()
            for li_ele in prerequisites:
                preq_arr.append(li_ele.text.strip())
            overview = page.find("div",{"class":"course-pagestyles__CourseContentIntro-sc-zxcngm-12 woWWD"}).findAll("strong")[0].text.strip()
            if(page.find("main" , {"class":"course-pagestyles__Left-sc-zxcngm-18 ksLrKK course-overview"}).findAll("div")[2].find("ul")):
                syllabus = page.find("main" , {"class":"course-pagestyles__Left-sc-zxcngm-18 ksLrKK course-overview"}).findAll("div")[2].findAll("ul")
                for li_ele in syllabus:
                    syllabus_arr.append(li_ele.text.strip())
            soup = BeautifulSoup(requests.get(course_url).content, "html.parser")
            reviews = soup.select("[class*=TestimonialStatement]")
            images = [] 
            name = soup.select("[class*=TestimonialName]")
            course_review = []
            for i in soup.select("[class*=TestimonialImage]"):
                images.append(i.find("picture").find("img"))
#           Reviews
            for i in range(0 , len(name) , 1):
                data = {
                    "name":name[i].text.strip(),
                    "description":reviews[i].text.strip(),
                    "image":"https://i.pinimg.com/564x/bb/2a/93/bb2a93fd5356e62db3033ae3dbefa4a7.jpg"
                }
                course_review.append(data)
#           Reviews
#           Videos Name and Durations
            soup = BeautifulSoup(requests.get(course_url).content, "html.parser")
            duration = soup.select("[class*=curriculum-sectionstyles__LectureCount-sc-nii9zc-7]")
            lectures = soup.select("[class*=curriculum-sectionstyles__SectionTitle-sc-nii9zc-6]")
            sub_lectures = soup.select("[class*=curriculum-sectionstyles__LectureTitle-sc-nii9zc-12]")
            ind = 0;
            course_syllabus_data = []
            
            
            for i in range(0 , len(duration) , 1):
                course_data_lst = {
                    "Lectures_Name":lectures[i].text.strip(),
                    "Lecture_Duration":duration[i].text.strip()
                }
                sub_lectures_syllabus = []
                index = int(duration[i].text.strip().split(" ")[0])
                while(ind < index):
                    sub_lectures_name = ""
                    sub_lectures_duration=  "" 
                    if "•" in sub_lectures[ind].text:
                        lst = sub_lectures[ind].text.strip().split("•")
                        sub_lectures_name = lst[0].strip()
                        sub_lectures_duration = lst[1]
                    else:
                        sub_lectures_name = sub_lectures[ind].text.strip()
                        sub_lectures_duration = 0
                    sub_lectures_syllabus.append({
                        "sub_lectures_name":sub_lectures_name,
                        "sub_lectures_duration":sub_lectures_duration
                    })
                    ind+=1;
                course_data_lst["sub_lectures_syllabus"] = sub_lectures_syllabus
                course_syllabus_data.append(course_data_lst)
            course_data["videos"] = course_syllabus_data
            course_data["reviews"] = course_review
            course_data["Contents"] = {
                "resources":resources,
                "projects":projects
            }
            course_data["Last_Updated"] = last_updated
            course_data["course_img"] = "https:"+page.find("div",{"class":"vimeo-styles__VimeoLazyContainer-sc-n9r7d2-1 kvujne"}).findAll("img")[0]["src"]
            course_data["Title"] = title
            course_data["Description_two"] = description_two
            course_data["Syllabus"] = syllabus_arr
            course_data["Prerequisites"] = preq_arr
            course_data["Overview"] = overview
            course_data["Topics_You_Will_Learn"] = Topics_You_Will_Learn
            entire_data.append(course_data)
couse_details = json.dumps(entire_data, indent = 4) 
print(couse_details)
# Out:
# [
#     {
#         "course_img": "https://images.ctfassets.net/aq13lwl6616q/5Vsjisy7BEI69JhQoonaZh/da516410801b8124dc049c84bbf07958/complete_web_developer_in_2022_zero_to_mastery.png?w=700&fm=webp",
#         "Title": "The Complete Web Developer in 2022",
#         "Duration": "38 Hours",
#         "Lessons": "383 Lessons",
#         "Description_one": "Learn to code from scratch and get hired as a Web Developer in 2022. This full-stack coding bootcamp will teach you HTML, CSS, JavaScript, React, Node.js, Machine Learning & more.",
#         "Description_two": "Learn to code. Get hired. This is one of the most popular, highly rated coding bootcamps online. It's also the most moderen and up-to-date. Guaranteed. You'll go from complete beginner to learing to code and getting hired as a Developer (this year!) at companies like Google, Tesla, and Amazon.",
#         "Type": "Beginner",
#         "Last_Updated": "July 2022",
#         "Contents": {
# ...
